# %%
import json
import pandas as pd

# %%
df = pd.read_csv("Data/final_tmdb_data_2000.csv.gz", low_memory = False)
df.sample(1000)
# Out:
#         imdb_id  adult                     backdrop_path  \
# 608   tt0224086    0.0                               NaN
# 213   tt0183488    0.0                               NaN
# 442   tt0210567    0.0  /e0rLPw4rPgXjvMjH3NwcoTWYvnl.jpg
# 1069  tt0291043    0.0                               NaN
# 125   tt0164212    0.0  /ca5hO15TfLe7MoAFYW6lCXwlaLX.jpg
# ...         ...    ...                               ...
# 51    tt0144574    0.0                               NaN
# 719   tt0238588    0.0                               NaN
# 805   tt0246875    0.0  /npuiLeBAjMF1PpJhLpwWqpt0I8M.jpg
# 108   tt0160859    0.0                               NaN
# 535   tt0218112    0.0  /uulJ0YS8fYR1qyetKLOUfueq5Bd.jpg
#
#                                   belongs_to_collection      budget  \
# 608   {'id': 432207, 'name': 'The Sex Files', 'poste...         0.0
# 213                                                 NaN         0.0
# 442                                                 NaN         0.0
# ...

# %%
df['imdb_id']
# Out:
# 0               0
# 1       tt0113026
# 2       tt0113092
# 3       tt0116391
# 4       tt0118694
#           ...
# 1210    tt6174238
# 1211    tt7029820
# 1212    tt7197642
# 1213    tt7631368
# 1214    tt7802790
# Name: imdb_id, Length: 1215, dtype: object
